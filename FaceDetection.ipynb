# %%
import cv2
from google.colab.patches import cv2_imshow
from IPython.display import clear_output 

# cascade file
cascPath = "/content/haarcascade_frontalface_default.xml"

# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
# load the video
cap = cv2.VideoCapture('Faces.mp4')

if (cap.isOpened()== False): 
  print("Error opening video stream or file :( ")

# for perf issues
counter = 0;

# Read until video is completed
while(cap.isOpened()):
  ret, frame = cap.read()

  if counter == 1:
    counter = 0
    continue

  counter = counter + 1

  if ret == True:
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = faceCascade.detectMultiScale(
        gray, scaleFactor=1.1, minNeighbors=5,minSize=(30,30)
    )

    for (x,y,w,h) in faces:
      cv2.rectangle(frame, (x,y), (x+h,y+w), (0,255,0),2)

    clear_output()

    # Display the resulting frame with rectangle for the head
    cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7FD8AEAD3A10>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-e8abbfcd0da5> in <module>()
#      22
#      23     faces = faceCascade.detectMultiScale(
# ---> 24         gray, scaleFactor=1.1, minNeighbors=5,minSize=(30,30)
#      25     )
#      26
#
# KeyboardInterrupt:
